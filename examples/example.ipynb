# %%
# %load_ext autoreload
# %autoreload 2

# %%
from beavermap.generate import BeaverMap
bm = BeaverMap(
    h5_file = './data/al2o3_m330p0/al2o3_m330p0.h5',
    poni = './data/m330p0.poni',
    mask = './data/mask.edf',
    chunk_size = 100,
)

# %% [markdown]
# 1. Max Summation

# %%
max_sum = bm.max_sum(ncpus=4,tqdm_kwargs={'ncols':None})
# Out:
# performing max summation:   0%|          | 0/72 [00:00<?, ?it/s]

# %% [markdown]
# (plotting options to follow)

# %%
from beavermap.analysis import BeaverMapPeakFinder 
# work in progress

bmpf = BeaverMapPeakFinder(bm)

peaks = bmpf.peak_finder(**{'prominence':50})

# %% [markdown]
# 2. integration

# %%
regions = [[0,5],[6,10]]
integration = bm.integrate(ncpus=4,regions=regions,tqdm_kwargs={'ncols':None})

# %%
from beavermap.plotting import BeaverMapPlotter
import numpy as np 
import glob 

files = sorted(glob.glob('./path/to/patches/*.npz'))
files = sorted(glob.glob('/Users/badw/Desktop/sofie/54_T1_2/*/*.npz'))

mapping = np.array([[0,3],
                    [1,4],
                    [2,5]])

bmp = BeaverMapPlotter(files,mapping,normalise_patches_method='median')
fig,axes = bmp.plot_combined(
    #index=14,
    ncols=10,
    normalise_index_over_all=True,
    figsize=(20,20),
    scale_bar=True,
    colourbar=False,
    annotate=False,
    gridspec_kw={"wspace": 0, "hspace": 0},
    aspect='auto',
    cmap='magma'
    )
